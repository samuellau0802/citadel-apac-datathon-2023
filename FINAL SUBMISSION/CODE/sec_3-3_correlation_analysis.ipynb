# %%
import pandas as pd
import seaborn as sns

# %%
df_monthly_district = pd.read_csv("data/monthly_district_data.csv")
df_monthly_district.head()
# Out:
#    Unnamed: 0  Unnamed: 1  crime_crime_Aggravated Assault Firearm  \
# 0         1.0  2014-01-31                                     1.0
# 1         1.0  2014-02-28                                     2.0
# 2         1.0  2014-03-31                                     3.0
# 3         1.0  2014-04-30                                     5.0
# 4         1.0  2014-05-31                                     1.0
#
#    crime_crime_Aggravated Assault No Firearm  crime_crime_All Other Offenses  \
# 0                                        9.0                            26.0
# 1                                        8.0                            46.0
# 2                                       10.0                            83.0
# 3                                        8.0                            78.0
# 4                                       12.0                            55.0
#
#    crime_crime_Arson  crime_crime_Burglary Non-Residential  \
# 0                0.0                                   1.0
# 1                0.0                                   1.0
# 2                1.0                                   1.0
# 3                1.0                                   3.0
# 4                0.0                                   1.0
#
#    crime_crime_Burglary Residential  crime_crime_DRIVING UNDER THE INFLUENCE  \
# 0                              10.0                                      7.0
# 1                               7.0                                      8.0
# 2                               6.0                                      6.0
# 3                              10.0                                      7.0
# 4                              11.0                                      4.0
#
#    crime_crime_Disorderly Conduct  ...  traffic_stop_subject_sex_male  \
# 0                             3.0  ...                          286.0
# 1                             2.0  ...                          857.0
# 2                             5.0  ...                          760.0
# 3                             3.0  ...                         1108.0
# 4                             6.0  ...                         1054.0
#
#    traffic_stop_type_pedestrian  traffic_stop_type_vehicular  \
# 0                         146.0                        236.0
# 1                         519.0                        613.0
# 2                         481.0                        512.0
# 3                         730.0                        755.0
# 4                         690.0                        729.0
#
#    traffic_stop_outcome_arrest  traffic_stop_outcome_none  \
# 0                         12.0                      370.0
# 1                         39.0                     1093.0
# 2                         28.0                      965.0
# 3                         52.0                     1433.0
# 4                         45.0                     1374.0
#
#    traffic_stop_contraband_found  traffic_stop_frisk_performed  \
# 0                            2.0                          23.0
# 1                           12.0                          65.0
# 2                           10.0                          63.0
# 3                           14.0                         101.0
# 4                           14.0                         102.0
#
#    traffic_stop_search_conducted  traffic_stop_arrest_made  traffic_stop_total
# 0                           14.0                      12.0              1579.0
# 1                           40.0                      39.0              4684.0
# 2                           29.0                      28.0              4102.0
# 3                           49.0                      52.0              6156.0
# 4                           50.0                      45.0              5887.0
#
# [5 rows x 190 columns]

# %%
df_monthly_district = df_monthly_district[[
 'crime_total',
 'traffic_stop_total',
 'crash_total']]

# %% [markdown]
# ## Crime/Traffic Stop to The No. of Car Crashes

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
sns.regplot(ax=axs[0], data=df_monthly_district, x="crime_total", y="crash_total", line_kws={'color': 'red'})
sns.regplot(ax=axs[1], data=df_monthly_district, x="traffic_stop_total", y="crash_total", line_kws={'color': 'red'})
axs[0].set_title("No. of Crimes to No. of Car Crashes")
axs[1].set_title("No. of Traffic Stops to No. of Car Crashes")
# Out:
# Text(0.5, 1.0, 'No. of Traffic Stops to No. of Car Crashes')

# %%
from scipy.stats import pearsonr
corr0, p0 = pearsonr(df_monthly_district["crime_total"], df_monthly_district["crash_total"])
corr1, p1 = pearsonr(df_monthly_district["traffic_stop_total"], df_monthly_district["crash_total"])
print(f"No. of Crimes to No. of Car Crashes: ")
print(f"Perarson Coefficient: {round(corr0, 3)}        p-value: {p0}")
print(f"No. of Traffic Stops to No. of Car Crashes:")
print(f"Perarson Coefficient: {round(corr1, 3)}        p-value: {p1}")
# Out:
# No. of Crimes to No. of Car Crashes:
# Perarson Coefficient: 0.555        p-value: 3.9156375782244206e-90
# No. of Traffic Stops to No. of Car Crashes:
# Perarson Coefficient: 0.321        p-value: 9.3984805873943e-28

# %%
from statsmodels.graphics.gofplots import qqplot
from scipy.stats import norm, uniform
import numpy as np

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
qqplot(df_monthly_district["crime_total"],norm,fit=True,line="45", ax=axs[0])
axs[0].set_title("crime_total Q-Q plot")
qqplot(df_monthly_district["traffic_stop_total"],norm,fit=True,line="45", ax=axs[1])
axs[1].set_title("traffic_stop_total Q-Q plot")
qqplot(df_monthly_district["crash_total"],norm,fit=True,line="45", ax=axs[2])
axs[2].set_title("crash_total Q-Q plot")
plt.tight_layout()
plt.show()
